# %% [markdown]
# # Can You Round?
#
# Let's look at the following integer program that will first solve as a linear program.
#
# $\max 20x_{1} + 10x_{2} + 10x_{3}$
#
# subject to
#
# $2x_{1} + 20x_{2} + 4x_{3} \leq 15$
#
# $6x_{1} + 20x_{2} + 4x_{3} = 20$
#
# $x_{1}, x_{2}, x_{3} \in \mathbb{Z}^{+}$

# %%
# import packages
import gurobipy as gp
from gurobipy import GRB

# %%
# Create the model

# %%
# Create the variables

# %%
# Create Objective function

# %%
# Add constraints

# %%
# Optimize

# %%
# See the variable results
for v in m.getVars():
    print(f'{v.varName} = {v.X}')

# %%
# Now set the variables to be integer
for v in m.getVars():
    v.setAttr(GRB.Attr.VType, GRB.INTEGER)

m.update()
m.display()

# %%
# Solve the IP
m.optimize()

# %%
# See the results for the IP
for v in m.getVars():
    print(f'{v.varName} = {v.X}')
