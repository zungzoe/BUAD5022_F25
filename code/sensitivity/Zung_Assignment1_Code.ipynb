# %% [markdown]
# ## LP Model for January

# %%
# import the two Gurobi parts we need for the whole notebook
import gurobipy as gp
from gurobipy import GRB

# %% [markdown]
# ### Formulation
#
# | | | |
# | --- | --- | --- |
# | Let | | |
# | $x_{1}$ | = | number of TorqueMaster 9000 Spindle Hub to produce this month |
# | $x_{2}$ | = | number of CryoLock Precision Valve Body to produce this month |
# | $x_{3}$ | = | number of Axial-Flex Gear Coupler to produce this month |
# | $x_{4}$ | = | number of HydroForge Pump Manifold to produce this month |
# | $x_{5}$ | = | number of ThermaCore Brake Rotor Sleeve to produce this month |
# | $x_{6}$ | = | number of MagnoRail Linear Slide Base to produce this month |
# | $x_{7}$ | = | number of VibeShield Housing Plate to produce this month |
#
# $\max.$ $\big[10x_{1}$ $+$ $6x_{2}$ $+$ $8x_{3}$ $+$ $4x_{4}$ $+$ $11x_{5}$ $+$ $9x_{6}$ $+$ $3x_{7}\big]$
#
# | | | | | | | | | | | | | |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | s.t. | $0.5x_{1}$ | $+$ | $0.7x_{2}$ | $+$ | $0.3x_{5}$ | $+$ | $0.2x_{6}$ | $+$ | $0.5x_{7}$ | $\le$ | $1152$ | {3 grinders: hours} |
# | | | | $0.1x_{1}$ | $+$ | $0.2x_{2}$ | $+$ | $0.3x_{4}$ | $+$ | $0.6x_{6}$ | $\le$ | $768$ | {2 vertical drills: hours} |
# | | | | | | $0.2x_{1}$ | $+$ | $0.8x_{3}$ | $+$ | $0.6x_{7}$ | $\le$ | $1152$ | {3 horizontal drills: hours} |
# | | $0.05x_{1}$ | $+$ | $0.03x_{2}$ | $+$ | $0.07x_{4}$ | $+$ | $0.1x_{5}$ | $+$ | $0.08x_{7}$ | $\le$ | $384$ | {1 borer: hours} |
# | | | | | | $0.01x_{3}$ | $+$ | $0.05x_{5}$ | $+$ | $0.05x_{7}$ | $\le$ | $384$ | {1 planer: hours} |
# | | | | | | | | | | $x_{1}$ | $\le$ | $500$ | {TorqueMaster production limit} |
# | | | | | | | | | | $x_{2}$ | $\le$ | $1000$ | {CryoLock production limit} |
# | | | | | | | | | | $x_{3}$ | $\le$ | $300$ | {Axial-Flex production limit} |
# | | | | | | | | | | $x_{4}$ | $\le$ | $300$ | {HydroForge production limit} |
# | | | | | | | | | | $x_{5}$ | $\le$ | $800$ | {ThermaCore production limit} |
# | | | | | | | | | | $x_{6}$ | $\le$ | $200$ | {MagnoRail production limit} |
# | | | | | | | | | | $x_{7}$ | $\le$ | $100$ | {VibeShield production limit} |
# | | | | $x_{1}$ | $x_{2}$ | $x_{3}$ | $x_{4}$ | $x_{5}$ | $x_{6}$ | $x_{7}$ | $\ge$ | $0$ | {non-negativity} |

# %% [markdown]
# ### Creating January's Gurobi Model

# %%
# Create the model object
m = gp.Model('january_production')
# Out:
# Restricted license - for non-production use only - expires 2026-11-23

# %%
# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Update the model
m.update()

# %%
# Creating the decision variables
x_1 = m.addVar(vtype=GRB.CONTINUOUS, name='x_1', lb=0.0)
x_2 = m.addVar(vtype=GRB.CONTINUOUS, name='x_2', lb=0.0)
x_3 = m.addVar(vtype=GRB.CONTINUOUS, name='x_3', lb=0.0)
x_4 = m.addVar(vtype=GRB.CONTINUOUS, name='x_4', lb=0.0)
x_5 = m.addVar(vtype=GRB.CONTINUOUS, name='x_5', lb=0.0)
x_6 = m.addVar(vtype=GRB.CONTINUOUS, name='x_6', lb=0.0)
x_7 = m.addVar(vtype=GRB.CONTINUOUS, name='x_7', lb=0.0)

# update the model
m.update()

# %%
# Adding the objective function
m.setObjective(10 * x_1 + 6 * x_2 + 8 * x_3 + 4 * x_4 + 11 * x_5 + 9 * x_6 + 3 * x_7)
m.update()

# %%
# Adding the constraints
m.addConstr(0.5 * x_1 + 0.7 * x_2 + 0.3 * x_5 + 0.2 * x_6 + 0.5 * x_7 <= 1152, name = 'grinder')
m.addConstr(0.1 * x_1 + 0.2 * x_2 + 0.3 * x_4 + 0.6 * x_6 <= 768, name = 'vertical')
m.addConstr(0.2 * x_1 + 0.8 * x_3 + 0.6 * x_7 <= 1152, name = 'horizontal')
m.addConstr(0.05 * x_1 + 0.03 * x_2 + 0.07 * x_4 + 0.1 * x_5 + 0.08 * x_7 <= 384, name = 'borer')
m.addConstr(0.01 * x_3 + 0.05 * x_5 + 0.05 * x_7 <= 384, name = 'planer')
m.addConstr(x_1 <= 500, name = 'torquemaster')
m.addConstr(x_2 <= 1000, name = 'cryolock')
m.addConstr(x_3 <= 300, name = 'axialflex')
m.addConstr(x_4 <= 300, name = 'hydroforge')
m.addConstr(x_5 <= 800, name = 'thermacore')
m.addConstr(x_6 <= 200, name = 'magnorail')
m.addConstr(x_7 <= 100, name = 'vibeshield')
m.update()

# %%
# View the LP
m.display()
# Out:
# Maximize
#   10.0 x_1 + 6.0 x_2 + 8.0 x_3 + 4.0 x_4 + 11.0 x_5 + 9.0 x_6 + 3.0 x_7
# Subject To
#   grinder: 0.5 x_1 + 0.7 x_2 + 0.3 x_5 + 0.2 x_6 + 0.5 x_7 <= 1152
#   vertical: 0.1 x_1 + 0.2 x_2 + 0.3 x_4 + 0.6 x_6 <= 768
#   horizontal: 0.2 x_1 + 0.8 x_3 + 0.6 x_7 <= 1152
#   borer: 0.05 x_1 + 0.03 x_2 + 0.07 x_4 + 0.1 x_5 + 0.08 x_7 <= 384
#   planer: 0.01 x_3 + 0.05 x_5 + 0.05 x_7 <= 384
#   torquemaster: x_1 <= 500
#   cryolock: x_2 <= 1000
#   axialflex: x_3 <= 300
#   hydroforge: x_4 <= 300
#   thermacore: x_5 <= 800
#   magnorail: x_6 <= 200
#   vibeshield: x_7 <= 100
# C:\Users\zungz\AppData\Local\Temp\ipykernel_34928\1574255693.py:2: DeprecationWarning: Model.display() is deprecated
#   m.display()

# %%
# Solve
m.optimize()
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0xbb536dc7
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+03]
# Presolve removed 11 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5440000e+04   3.475000e+02   0.000000e+00      0s
#        1    2.4531429e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.453142857e+04

# %%
# Getting the results out
print(f'To generate the optimal profit of ${m.ObjVal:0.2f}, you should produce the following amounts:')
for v in m.getVars():
    print(f'   {v.VarName} = {v.X}')
# Out:
# To generate the optimal profit of $24531.43, you should produce the following amounts:
#    x_1 = 500.0
#    x_2 = 888.5714285714287
#    x_3 = 300.0
#    x_4 = 300.0
#    x_5 = 800.0
#    x_6 = 200.0
#    x_7 = 0.0

# %% [markdown]
# ### January Sensitivity Analysis

# %%
# Importing the function
import sensitivity_analysis as sp

# %%
# Printing out feasability
sp.sa_constrs(m.getConstrs())
# Out:
#                  binding?  final_value     RHS       slack  shadow_price  \
# grinder           binding  1152.000000  1152.0    0.000000      8.571429
# vertical      non-binding   437.714286   768.0  330.285714      0.000000
# horizontal    non-binding   340.000000  1152.0  812.000000      0.000000
# borer         non-binding   152.657143   384.0  231.342857      0.000000
# planer        non-binding    43.000000   384.0  341.000000      0.000000
# torquemaster      binding   500.000000   500.0    0.000000      5.714286
# cryolock      non-binding   888.571429  1000.0  111.428571      0.000000
# axialflex         binding   300.000000   300.0    0.000000      8.000000
# hydroforge        binding   300.000000   300.0    0.000000      4.000000
# thermacore        binding   800.000000   800.0    0.000000      8.428571
# magnorail         binding   200.000000   200.0    0.000000      7.285714
# vibeshield    non-binding     0.000000   100.0  100.000000      0.000000
#
#               range_feas_low  range_feas_high
# grinder           530.000000      1230.000000
# vertical          437.714286              inf
# horizontal        340.000000              inf
# borer             152.657143              inf
# planer             43.000000              inf
# torquemaster      344.000000      1744.000000
# cryolock          888.571429              inf
# axialflex           0.000000      1315.000000
# hydroforge          0.000000      1400.952381
# thermacore        540.000000      2873.333333
# magnorail           0.000000       808.421053
# vibeshield          0.000000              inf

# %% [markdown]
# ## LP Model For February - June

# %% [markdown]
# ### February

# %%
# Create the model object
m = gp.Model('february_production')

# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Creating the decision variables
x_1 = m.addVar(vtype=GRB.CONTINUOUS, name='x_1', lb=0.0)
x_2 = m.addVar(vtype=GRB.CONTINUOUS, name='x_2', lb=0.0)
x_3 = m.addVar(vtype=GRB.CONTINUOUS, name='x_3', lb=0.0)
x_4 = m.addVar(vtype=GRB.CONTINUOUS, name='x_4', lb=0.0)
x_5 = m.addVar(vtype=GRB.CONTINUOUS, name='x_5', lb=0.0)
x_6 = m.addVar(vtype=GRB.CONTINUOUS, name='x_6', lb=0.0)
x_7 = m.addVar(vtype=GRB.CONTINUOUS, name='x_7', lb=0.0)

# Adding the objective function
m.setObjective(10 * x_1 + 6 * x_2 + 8 * x_3 + 4 * x_4 + 11 * x_5 + 9 * x_6 + 3 * x_7)

# Adding the constraints
m.addConstr(0.5 * x_1 + 0.7 * x_2 + 0.3 * x_5 + 0.2 * x_6 + 0.5 * x_7 <= 1536, name = 'grinder')
m.addConstr(0.1 * x_1 + 0.2 * x_2 + 0.3 * x_4 + 0.6 * x_6 <= 768, name = 'vertical')
m.addConstr(0.2 * x_1 + 0.8 * x_3 + 0.6 * x_7 <= 384, name = 'horizontal')
m.addConstr(0.05 * x_1 + 0.03 * x_2 + 0.07 * x_4 + 0.1 * x_5 + 0.08 * x_7 <= 384, name = 'borer')
m.addConstr(0.01 * x_3 + 0.05 * x_5 + 0.05 * x_7 <= 384, name = 'planer')
m.addConstr(x_1 <= 600, name = 'torquemaster')
m.addConstr(x_2 <= 500, name = 'cryolock')
m.addConstr(x_3 <= 200, name = 'axialflex')
m.addConstr(x_4 <= 0, name = 'hydroforge')
m.addConstr(x_5 <= 400, name = 'thermacore')
m.addConstr(x_6 <= 300, name = 'magnorail')
m.addConstr(x_7 <= 150, name = 'vibeshield')
m.update()

# Solve
m.optimize()

# Getting the results out
print(f'To generate the optimal profit of ${m.ObjVal:0.2f}, you should produce the following amounts:')
for v in m.getVars():
    print(f'   {v.VarName} = {v.X}')
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0x1534507b
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 2e+03]
# Presolve removed 12 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8150000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.815000000e+04
# To generate the optimal profit of $18150.00, you should produce the following amounts:
#    x_1 = 600.0
#    x_2 = 500.0
#    x_3 = 200.0
#    x_4 = 0.0
#    x_5 = 400.0
#    x_6 = 300.0
#    x_7 = 150.0

# %% [markdown]
# ### March

# %%
# Create the model object
m = gp.Model('march_production')

# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Creating the decision variables
x_1 = m.addVar(vtype=GRB.CONTINUOUS, name='x_1', lb=0.0)
x_2 = m.addVar(vtype=GRB.CONTINUOUS, name='x_2', lb=0.0)
x_3 = m.addVar(vtype=GRB.CONTINUOUS, name='x_3', lb=0.0)
x_4 = m.addVar(vtype=GRB.CONTINUOUS, name='x_4', lb=0.0)
x_5 = m.addVar(vtype=GRB.CONTINUOUS, name='x_5', lb=0.0)
x_6 = m.addVar(vtype=GRB.CONTINUOUS, name='x_6', lb=0.0)
x_7 = m.addVar(vtype=GRB.CONTINUOUS, name='x_7', lb=0.0)

# Adding the objective function
m.setObjective(10 * x_1 + 6 * x_2 + 8 * x_3 + 4 * x_4 + 11 * x_5 + 9 * x_6 + 3 * x_7)

# Adding the constraints
m.addConstr(0.5 * x_1 + 0.7 * x_2 + 0.3 * x_5 + 0.2 * x_6 + 0.5 * x_7 <= 1536, name = 'grinder')
m.addConstr(0.1 * x_1 + 0.2 * x_2 + 0.3 * x_4 + 0.6 * x_6 <= 768, name = 'vertical')
m.addConstr(0.2 * x_1 + 0.8 * x_3 + 0.6 * x_7 <= 1152, name = 'horizontal')
m.addConstr(0.05 * x_1 + 0.03 * x_2 + 0.07 * x_4 + 0.1 * x_5 + 0.08 * x_7 <= 0, name = 'borer')
m.addConstr(0.01 * x_3 + 0.05 * x_5 + 0.05 * x_7 <= 384, name = 'planer')
m.addConstr(x_1 <= 300, name = 'torquemaster')
m.addConstr(x_2 <= 600, name = 'cryolock')
m.addConstr(x_3 <= 0, name = 'axialflex')
m.addConstr(x_4 <= 0, name = 'hydroforge')
m.addConstr(x_5 <= 500, name = 'thermacore')
m.addConstr(x_6 <= 400, name = 'magnorail')
m.addConstr(x_7 <= 100, name = 'vibeshield')
m.update()

# Solve
m.optimize()

# Getting the results out
print(f'To generate the optimal profit of ${m.ObjVal:0.2f}, you should produce the following amounts:')
for v in m.getVars():
    print(f'   {v.VarName} = {v.X}')
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0x8b90440c
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 2e+03]
# Presolve removed 12 rows and 7 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6000000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.600000000e+03
# To generate the optimal profit of $3600.00, you should produce the following amounts:
#    x_1 = 0.0
#    x_2 = 0.0
#    x_3 = 0.0
#    x_4 = 0.0
#    x_5 = 0.0
#    x_6 = 400.0
#    x_7 = 0.0

# %% [markdown]
# ### April

# %%
# Create the model object
m = gp.Model('april_production')

# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Creating the decision variables
x_1 = m.addVar(vtype=GRB.CONTINUOUS, name='x_1', lb=0.0)
x_2 = m.addVar(vtype=GRB.CONTINUOUS, name='x_2', lb=0.0)
x_3 = m.addVar(vtype=GRB.CONTINUOUS, name='x_3', lb=0.0)
x_4 = m.addVar(vtype=GRB.CONTINUOUS, name='x_4', lb=0.0)
x_5 = m.addVar(vtype=GRB.CONTINUOUS, name='x_5', lb=0.0)
x_6 = m.addVar(vtype=GRB.CONTINUOUS, name='x_6', lb=0.0)
x_7 = m.addVar(vtype=GRB.CONTINUOUS, name='x_7', lb=0.0)

# Adding the objective function
m.setObjective(10 * x_1 + 6 * x_2 + 8 * x_3 + 4 * x_4 + 11 * x_5 + 9 * x_6 + 3 * x_7)

# Adding the constraints
m.addConstr(0.5 * x_1 + 0.7 * x_2 + 0.3 * x_5 + 0.2 * x_6 + 0.5 * x_7 <= 1536, name = 'grinder')
m.addConstr(0.1 * x_1 + 0.2 * x_2 + 0.3 * x_4 + 0.6 * x_6 <= 384, name = 'vertical')
m.addConstr(0.2 * x_1 + 0.8 * x_3 + 0.6 * x_7 <= 1152, name = 'horizontal')
m.addConstr(0.05 * x_1 + 0.03 * x_2 + 0.07 * x_4 + 0.1 * x_5 + 0.08 * x_7 <= 384, name = 'borer')
m.addConstr(0.01 * x_3 + 0.05 * x_5 + 0.05 * x_7 <= 384, name = 'planer')
m.addConstr(x_1 <= 200, name = 'torquemaster')
m.addConstr(x_2 <= 300, name = 'cryolock')
m.addConstr(x_3 <= 400, name = 'axialflex')
m.addConstr(x_4 <= 500, name = 'hydroforge')
m.addConstr(x_5 <= 200, name = 'thermacore')
m.addConstr(x_6 <= 0, name = 'magnorail')
m.addConstr(x_7 <= 100, name = 'vibeshield')
m.update()

# Solve
m.optimize()

# Getting the results out
print(f'To generate the optimal profit of ${m.ObjVal:0.2f}, you should produce the following amounts:')
for v in m.getVars():
    print(f'   {v.VarName} = {v.X}')
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0x4b084abe
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 2e+03]
# Presolve removed 12 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1500000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.150000000e+04
# To generate the optimal profit of $11500.00, you should produce the following amounts:
#    x_1 = 200.0
#    x_2 = 300.0
#    x_3 = 400.0
#    x_4 = 500.0
#    x_5 = 200.0
#    x_6 = 0.0
#    x_7 = 100.0

# %% [markdown]
# ### May

# %%
# Create the model object
m = gp.Model('may_production')

# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Creating the decision variables
x_1 = m.addVar(vtype=GRB.CONTINUOUS, name='x_1', lb=0.0)
x_2 = m.addVar(vtype=GRB.CONTINUOUS, name='x_2', lb=0.0)
x_3 = m.addVar(vtype=GRB.CONTINUOUS, name='x_3', lb=0.0)
x_4 = m.addVar(vtype=GRB.CONTINUOUS, name='x_4', lb=0.0)
x_5 = m.addVar(vtype=GRB.CONTINUOUS, name='x_5', lb=0.0)
x_6 = m.addVar(vtype=GRB.CONTINUOUS, name='x_6', lb=0.0)
x_7 = m.addVar(vtype=GRB.CONTINUOUS, name='x_7', lb=0.0)

# Adding the objective function
m.setObjective(10 * x_1 + 6 * x_2 + 8 * x_3 + 4 * x_4 + 11 * x_5 + 9 * x_6 + 3 * x_7)

# Adding the constraints
m.addConstr(0.5 * x_1 + 0.7 * x_2 + 0.3 * x_5 + 0.2 * x_6 + 0.5 * x_7 <= 1152, name = 'grinder')
m.addConstr(0.1 * x_1 + 0.2 * x_2 + 0.3 * x_4 + 0.6 * x_6 <= 384, name = 'vertical')
m.addConstr(0.2 * x_1 + 0.8 * x_3 + 0.6 * x_7 <= 1152, name = 'horizontal')
m.addConstr(0.05 * x_1 + 0.03 * x_2 + 0.07 * x_4 + 0.1 * x_5 + 0.08 * x_7 <= 384, name = 'borer')
m.addConstr(0.01 * x_3 + 0.05 * x_5 + 0.05 * x_7 <= 384, name = 'planer')
m.addConstr(x_1 <= 0, name = 'torquemaster')
m.addConstr(x_2 <= 100, name = 'cryolock')
m.addConstr(x_3 <= 500, name = 'axialflex')
m.addConstr(x_4 <= 100, name = 'hydroforge')
m.addConstr(x_5 <= 1000, name = 'thermacore')
m.addConstr(x_6 <= 300, name = 'magnorail')
m.addConstr(x_7 <= 0, name = 'vibeshield')
m.update()

# Solve
m.optimize()

# Getting the results out
print(f'To generate the optimal profit of ${m.ObjVal:0.2f}, you should produce the following amounts:')
for v in m.getVars():
    print(f'   {v.VarName} = {v.X}')
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0x477f7cf9
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+03]
# Presolve removed 12 rows and 7 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8700000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.870000000e+04
# To generate the optimal profit of $18700.00, you should produce the following amounts:
#    x_1 = 0.0
#    x_2 = 100.0
#    x_3 = 500.0
#    x_4 = 100.0
#    x_5 = 1000.0
#    x_6 = 300.0
#    x_7 = 0.0

# %% [markdown]
# ### June

# %%
# Create the model object
m = gp.Model('june_production')

# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Creating the decision variables
x_1 = m.addVar(vtype=GRB.CONTINUOUS, name='x_1', lb=0.0)
x_2 = m.addVar(vtype=GRB.CONTINUOUS, name='x_2', lb=0.0)
x_3 = m.addVar(vtype=GRB.CONTINUOUS, name='x_3', lb=0.0)
x_4 = m.addVar(vtype=GRB.CONTINUOUS, name='x_4', lb=0.0)
x_5 = m.addVar(vtype=GRB.CONTINUOUS, name='x_5', lb=0.0)
x_6 = m.addVar(vtype=GRB.CONTINUOUS, name='x_6', lb=0.0)
x_7 = m.addVar(vtype=GRB.CONTINUOUS, name='x_7', lb=0.0)

# Adding the objective function
m.setObjective(10 * x_1 + 6 * x_2 + 8 * x_3 + 4 * x_4 + 11 * x_5 + 9 * x_6 + 3 * x_7)

# Adding the constraints
m.addConstr(0.5 * x_1 + 0.7 * x_2 + 0.3 * x_5 + 0.2 * x_6 + 0.5 * x_7 <= 1536, name = 'grinder')
m.addConstr(0.1 * x_1 + 0.2 * x_2 + 0.3 * x_4 + 0.6 * x_6 <= 768, name = 'vertical')
m.addConstr(0.2 * x_1 + 0.8 * x_3 + 0.6 * x_7 <= 768, name = 'horizontal')
m.addConstr(0.05 * x_1 + 0.03 * x_2 + 0.07 * x_4 + 0.1 * x_5 + 0.08 * x_7 <= 384, name = 'borer')
m.addConstr(0.01 * x_3 + 0.05 * x_5 + 0.05 * x_7 <= 0, name = 'planer')
m.addConstr(x_1 <= 500, name = 'torquemaster')
m.addConstr(x_2 <= 500, name = 'cryolock')
m.addConstr(x_3 <= 100, name = 'axialflex')
m.addConstr(x_4 <= 300, name = 'hydroforge')
m.addConstr(x_5 <= 1100, name = 'thermacore')
m.addConstr(x_6 <= 500, name = 'magnorail')
m.addConstr(x_7 <= 60, name = 'vibeshield')
m.update()

# Solve
m.optimize()

# Getting the results out
print(f'To generate the optimal profit of ${m.ObjVal:0.2f}, you should produce the following amounts:')
for v in m.getVars():
    print(f'   {v.VarName} = {v.X}')
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0x376db412
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 2e+03]
# Presolve removed 12 rows and 7 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3700000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.370000000e+04
# To generate the optimal profit of $13700.00, you should produce the following amounts:
#    x_1 = 500.0
#    x_2 = 500.0
#    x_3 = 0.0
#    x_4 = 300.0
#    x_5 = 0.0
#    x_6 = 500.0
#    x_7 = 0.0

# %% [markdown]
# ## Overall Multiperiod Model

# %% [markdown]
# ### Formulation
#
# | | | |
# | --- | --- | --- |
# | Let | | |
# | $x_{1t}$ | = | number of TorqueMaster 9000 Spindle Hubs produced in month $t$ |
# | $x_{2t}$ | = | number of CryoLock Precision Valve Bodies produced in month $t$ |
# | $x_{3t}$ | = | number of Axial-Flex Gear Couplers produced in month $t$ |
# | $x_{4t}$ | = | number of HydroForge Pump Manifolds produced in month $t$ |
# | $x_{5t}$ | = | number of ThermaCore Brake Rotor Sleeves produced in month $t$ |
# | $x_{6t}$ | = | number of MagnoRail Linear Slide Bases produced in month $t$ |
# | $x_{7t}$ | = | number of VibeShield Housing Plates produced in month $t$ |
# | $s_{1t}$–$s_{7t}$ | = | ending inventory of each product in month $t$ |
#
# $\max.$  $\sum_{t=1}^{6}\sum_{i=1}^{7}\big(p_i(s_{i,t-1}+x_{it}-s_{it}) - 0.5s_{it}\big)$
#
# $p_i$ = profit per unit of product $i$
#
# | | | | | | | | | | | | | |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | s.t. (for every month $t$) | $0.5x_{1t}$ | $+$ | $0.7x_{2t}$ | $+$ | $0.3x_{5t}$ | $+$ | $0.2x_{6t}$ | $+$ | $0.5x_{7t}$ | $\le$ | $H_{\text{grinder},t}$ | {grinding hours $H$ available in month $t$} |
# | | | |$0.1x_{1t}$ | $+$ | $0.2x_{2t}$ | $+$ | $0.3x_{4t}$ | $+$ | $0.6x_{6t}$ | $\le$ | $H_{\text{vertical},t}$ | {vertical drills hours} |
# | | | | | | $0.2x_{1t}$ | $+$ | $0.8x_{3t}$ | $+$ | $0.6x_{7t}$ | $\le$ | $H_{\text{horizontal},t}$ | {horizontal drills hours} |
# | | $0.05x_{1t}$ | $+$ | $0.03x_{2t}$ | $+$ | $0.07x_{4t}$ | $+$ | $0.1x_{5t}$ | $+$ | $0.08x_{7t}$ | $\le$ | $H_{\text{borer},t}$ | {borer hours} |
# | | | | | | $0.01x_{3t}$ | $+$ | $0.05x_{5t}$ | $+$ | $0.05x_{7t}$ | $\le$ | $H_{\text{planer},t}$ | {planer hours} |
# | | | | | | | | $s_{i,t-1}$ | $+$ | $x_{it}$ | $=$ | $d_{it}$ $+$ $s_{it}$ | {demand $d$ / inventory balance for each product $i$ and month $t$} |
# | | | | | | | | | | $s_{it}$ | $\le$ | $100$ | {max storage per product} |
# | | | | | | | | | | $s_{i0}$ | $=$ | $0$ | {no starting inventory} |
# | | | | | | | | | | $s_{i6}$ | $=$ | $50$ | {desired ending inventory at June} |
# | | | | | | | | | $x_{it}$ | $s_{it}$ | $\ge$ | $0$ | {non-negativity} |

# %% [markdown]
# ### Setting Up The Data in Lists

# %%
products = list(range(7)) # For 7 products
months = list(range(6)) # For months January to June
machines = ['grinder','vertical','horizontal','borer','planer']

# Profit (p) per unit of product i
profit = [10, 6, 8, 4, 11, 9, 3]

# Cost of $0.50 per unit per month
cost = 0.5

# Demand per month for each product
demand = [
    [500, 600, 300, 200, 0, 500], # x_1
    [1000, 500, 600, 300, 100, 500], # x_2
    [300, 200, 0, 400, 500, 100], # x_3
    [300, 0, 0, 500, 100, 300], # x_4
    [800, 400, 500, 200, 1000, 1100], # x_5
    [200, 300, 400, 0, 300, 500], # x_6
    [100, 150, 100, 100, 0, 60], # x_7
]

# Constraint matrices (LHS)

# Hours spent per product on each machine
constr_coeff = [
    [0.5, 0.7, 0.0, 0.0, 0.3, 0.2, 0.5], # grinder
    [0.1, 0.2, 0.0, 0.3, 0.0, 0.6, 0.0], # vertical
    [0.2, 0.0, 0.8, 0.0, 0.0, 0.0, 0.6], # horizontal
    [0.05, 0.03, 0.0, 0.07, 0.10, 0.0, 0.08], # borer
    [0.0, 0.0, 0.01, 0.0, 0.05, 0.0, 0.05], # planer
]

# Hours (H) available per month for each machine
constr_hours = [
    [1152, 1536, 1536, 1536, 1152, 1536], # grinder
    [768, 768, 768, 384, 384, 768], # vertical
    [1152, 384, 1152, 1152, 1152, 768], # horiztonal
    [384, 384, 0, 384, 384, 384], # borer
    [384, 384, 384, 384, 384, 0], # planer
]

# %% [markdown]
# ### Creating the Gurobi Model

# %%
# Create the model object
m = gp.Model('multiperiod_production')

# Looking for maximum profit
m.ModelSense = GRB.MAXIMIZE

# Creating the decision variables
x = [[m.addVar(vtype=GRB.CONTINUOUS, lb=0.0, name=f'x{i+1}_month{t+1}')
      for i in products] for t in months]
s = [[m.addVar(vtype=GRB.CONTINUOUS, lb=0.0, name=f's{i+1}_month{t+1}')
      for i in products] for t in months]

# Adding the objective function
obj_terms = []
for i in products:
    # January: sales = x - s
    obj_terms.append(profit[i]*(x[0][i] - s[0][i]) - cost*s[0][i])
    # Months 2-6: sales = s_{t-1} + x - s
    for t in months[1:]:
        obj_terms.append(profit[i]*(s[t-1][i] + x[t][i] - s[t][i]) - cost*s[t][i])
m.setObjective(gp.quicksum(obj_terms))

m.update()

# %% [markdown]
# ### Adding Constsraints

# %%
# Hours spent per product on each machine
for t in months:
    for m_idx in range(len(machines)):
        m.addLConstr(
            gp.quicksum(constr_coeff[m_idx][i]*x[t][i] for i in products),
            GRB.LESS_EQUAL,
            rhs = constr_hours[m_idx][t],
            name = f'{machines[m_idx]}_{t+1}'
        )

# Sales flow and demand constraints
for i in products:
    # January (no previous stock)
    m.addConstr(x[0][i] - s[0][i] <= demand[i][0], name=f'DemandCap_i{i+1}_month1')
    m.addConstr(x[0][i] - s[0][i] >= 0, name=f'NoNegSales_i{i+1}_month1')
    # Months 2–6
    for t in months[1:]:
        m.addConstr(s[t-1][i] + x[t][i] - s[t][i] <= demand[i][t],
                    name=f'DemandCap_i{i+1}_month{t+1}')
        m.addConstr(s[t-1][i] + x[t][i] - s[t][i] >= 0,
                    name=f'NoNegSales_i{i+1}_month{t+1}')

# Storage limit
for t in months:
    for i in products:
        m.addConstr(s[t][i] <= 100, name=f'StorageLimit_i{i+1}_month{t+1}')

# Ending inventory in June
for i in products:
    m.addConstr(s[5][i] >= 50, name=f'EndingInventory_i{i+1}')

m.update()

# %% [markdown]
# ### Solving The Multiperiod Model

# %%
# View the LP
m.display()
# Out:
# Maximize
# 10.0 x1_month1 + 6.0 x2_month1 + 8.0 x3_month1 + 4.0 x4_month1 + 11.0 x5_month1
# + 9.0 x6_month1 + 3.0 x7_month1 + 10.0 x1_month2 + 6.0 x2_month2 + 8.0 x3_month2
# + 4.0 x4_month2 + 11.0 x5_month2 + 9.0 x6_month2 + 3.0 x7_month2 + 10.0 x1_month3
# + 6.0 x2_month3 + 8.0 x3_month3 + 4.0 x4_month3 + 11.0 x5_month3 + 9.0 x6_month3
# + 3.0 x7_month3 + 10.0 x1_month4 + 6.0 x2_month4 + 8.0 x3_month4 + 4.0 x4_month4
# + 11.0 x5_month4 + 9.0 x6_month4 + 3.0 x7_month4 + 10.0 x1_month5 + 6.0 x2_month5
# + 8.0 x3_month5 + 4.0 x4_month5 + 11.0 x5_month5 + 9.0 x6_month5 + 3.0 x7_month5
# + 10.0 x1_month6 + 6.0 x2_month6 + 8.0 x3_month6 + 4.0 x4_month6 + 11.0 x5_month6
# + 9.0 x6_month6 + 3.0 x7_month6 + -0.5 s1_month1 + -0.5 s2_month1 + -0.5 s3_month1 +
# -0.5 s4_month1 + -0.5 s5_month1 + -0.5 s6_month1 + -0.5 s7_month1 + -0.5 s1_month2 +
# -0.5 s2_month2 + -0.5 s3_month2 + -0.5 s4_month2 + -0.5 s5_month2 + -0.5 s6_month2 +
# -0.5 s7_month2 + -0.5 s1_month3 + -0.5 s2_month3 + -0.5 s3_month3 + -0.5 s4_month3 +
# -0.5 s5_month3 + -0.5 s6_month3 + -0.5 s7_month3 + -0.5 s1_month4 + -0.5 s2_month4 +
# -0.5 s3_month4 + -0.5 s4_month4 + -0.5 s5_month4 + -0.5 s6_month4 + -0.5 s7_month4 +
# -0.5 s1_month5 + -0.5 s2_month5 + -0.5 s3_month5 + -0.5 s4_month5 + -0.5 s5_month5 +
# -0.5 s6_month5 + -0.5 s7_month5 + -10.5 s1_month6 + -6.5 s2_month6 + -8.5 s3_month6 +
# -4.5 s4_month6 + -11.5 s5_month6 + -9.5 s6_month6 + -3.5 s7_month6
# Subject To
# grinder_1: 0.5 x1_month1 + 0.7 x2_month1 + 0.3 x5_month1 + 0.2 x6_month1 + 0.5
#  x7_month1 <= 1152
#   vertical_1: 0.1 x1_month1 + 0.2 x2_month1 + 0.3 x4_month1 + 0.6 x6_month1 <= 768
#   horizontal_1: 0.2 x1_month1 + 0.8 x3_month1 + 0.6 x7_month1 <= 1152
# borer_1: 0.05 x1_month1 + 0.03 x2_month1 + 0.07 x4_month1 + 0.1 x5_month1 + 0.08
#  x7_month1 <= 384
#   planer_1: 0.01 x3_month1 + 0.05 x5_month1 + 0.05 x7_month1 <= 384
# grinder_2: 0.5 x1_month2 + 0.7 x2_month2 + 0.3 x5_month2 + 0.2 x6_month2 + 0.5
#  x7_month2 <= 1536
#   vertical_2: 0.1 x1_month2 + 0.2 x2_month2 + 0.3 x4_month2 + 0.6 x6_month2 <= 768
#   horizontal_2: 0.2 x1_month2 + 0.8 x3_month2 + 0.6 x7_month2 <= 384
# borer_2: 0.05 x1_month2 + 0.03 x2_month2 + 0.07 x4_month2 + 0.1 x5_month2 + 0.08
#  x7_month2 <= 384
#   planer_2: 0.01 x3_month2 + 0.05 x5_month2 + 0.05 x7_month2 <= 384
# grinder_3: 0.5 x1_month3 + 0.7 x2_month3 + 0.3 x5_month3 + 0.2 x6_month3 + 0.5
#  x7_month3 <= 1536
#   vertical_3: 0.1 x1_month3 + 0.2 x2_month3 + 0.3 x4_month3 + 0.6 x6_month3 <= 768
#   horizontal_3: 0.2 x1_month3 + 0.8 x3_month3 + 0.6 x7_month3 <= 1152
# borer_3: 0.05 x1_month3 + 0.03 x2_month3 + 0.07 x4_month3 + 0.1 x5_month3 + 0.08
#  x7_month3 <= 0
#   planer_3: 0.01 x3_month3 + 0.05 x5_month3 + 0.05 x7_month3 <= 384
# grinder_4: 0.5 x1_month4 + 0.7 x2_month4 + 0.3 x5_month4 + 0.2 x6_month4 + 0.5
#  x7_month4 <= 1536
#   vertical_4: 0.1 x1_month4 + 0.2 x2_month4 + 0.3 x4_month4 + 0.6 x6_month4 <= 384
#   horizontal_4: 0.2 x1_month4 + 0.8 x3_month4 + 0.6 x7_month4 <= 1152
# borer_4: 0.05 x1_month4 + 0.03 x2_month4 + 0.07 x4_month4 + 0.1 x5_month4 + 0.08
#  x7_month4 <= 384
#   planer_4: 0.01 x3_month4 + 0.05 x5_month4 + 0.05 x7_month4 <= 384
# grinder_5: 0.5 x1_month5 + 0.7 x2_month5 + 0.3 x5_month5 + 0.2 x6_month5 + 0.5
#  x7_month5 <= 1152
#   vertical_5: 0.1 x1_month5 + 0.2 x2_month5 + 0.3 x4_month5 + 0.6 x6_month5 <= 384
#   horizontal_5: 0.2 x1_month5 + 0.8 x3_month5 + 0.6 x7_month5 <= 1152
# borer_5: 0.05 x1_month5 + 0.03 x2_month5 + 0.07 x4_month5 + 0.1 x5_month5 + 0.08
#  x7_month5 <= 384
#   planer_5: 0.01 x3_month5 + 0.05 x5_month5 + 0.05 x7_month5 <= 384
# grinder_6: 0.5 x1_month6 + 0.7 x2_month6 + 0.3 x5_month6 + 0.2 x6_month6 + 0.5
#  x7_month6 <= 1536
#   vertical_6: 0.1 x1_month6 + 0.2 x2_month6 + 0.3 x4_month6 + 0.6 x6_month6 <= 768
#   horizontal_6: 0.2 x1_month6 + 0.8 x3_month6 + 0.6 x7_month6 <= 768
# borer_6: 0.05 x1_month6 + 0.03 x2_month6 + 0.07 x4_month6 + 0.1 x5_month6 + 0.08
#  x7_month6 <= 384
#   planer_6: 0.01 x3_month6 + 0.05 x5_month6 + 0.05 x7_month6 <= 0
#   DemandCap_i1_month1: x1_month1 + -1.0 s1_month1 <= 500
#   NoNegSales_i1_month1: x1_month1 + -1.0 s1_month1 >= 0
#   DemandCap_i1_month2: x1_month2 + s1_month1 + -1.0 s1_month2 <= 600
#   NoNegSales_i1_month2: x1_month2 + s1_month1 + -1.0 s1_month2 >= 0
#   DemandCap_i1_month3: x1_month3 + s1_month2 + -1.0 s1_month3 <= 300
#   NoNegSales_i1_month3: x1_month3 + s1_month2 + -1.0 s1_month3 >= 0
#   DemandCap_i1_month4: x1_month4 + s1_month3 + -1.0 s1_month4 <= 200
#   NoNegSales_i1_month4: x1_month4 + s1_month3 + -1.0 s1_month4 >= 0
#   DemandCap_i1_month5: x1_month5 + s1_month4 + -1.0 s1_month5 <= 0
#   NoNegSales_i1_month5: x1_month5 + s1_month4 + -1.0 s1_month5 >= 0
#   DemandCap_i1_month6: x1_month6 + s1_month5 + -1.0 s1_month6 <= 500
#   NoNegSales_i1_month6: x1_month6 + s1_month5 + -1.0 s1_month6 >= 0
#   DemandCap_i2_month1: x2_month1 + -1.0 s2_month1 <= 1000
#   NoNegSales_i2_month1: x2_month1 + -1.0 s2_month1 >= 0
#   DemandCap_i2_month2: x2_month2 + s2_month1 + -1.0 s2_month2 <= 500
#   NoNegSales_i2_month2: x2_month2 + s2_month1 + -1.0 s2_month2 >= 0
#   DemandCap_i2_month3: x2_month3 + s2_month2 + -1.0 s2_month3 <= 600
#   NoNegSales_i2_month3: x2_month3 + s2_month2 + -1.0 s2_month3 >= 0
#   DemandCap_i2_month4: x2_month4 + s2_month3 + -1.0 s2_month4 <= 300
#   NoNegSales_i2_month4: x2_month4 + s2_month3 + -1.0 s2_month4 >= 0
#   DemandCap_i2_month5: x2_month5 + s2_month4 + -1.0 s2_month5 <= 100
#   NoNegSales_i2_month5: x2_month5 + s2_month4 + -1.0 s2_month5 >= 0
#   DemandCap_i2_month6: x2_month6 + s2_month5 + -1.0 s2_month6 <= 500
#   NoNegSales_i2_month6: x2_month6 + s2_month5 + -1.0 s2_month6 >= 0
#   DemandCap_i3_month1: x3_month1 + -1.0 s3_month1 <= 300
#   NoNegSales_i3_month1: x3_month1 + -1.0 s3_month1 >= 0
#   DemandCap_i3_month2: x3_month2 + s3_month1 + -1.0 s3_month2 <= 200
#   NoNegSales_i3_month2: x3_month2 + s3_month1 + -1.0 s3_month2 >= 0
#   DemandCap_i3_month3: x3_month3 + s3_month2 + -1.0 s3_month3 <= 0
#   NoNegSales_i3_month3: x3_month3 + s3_month2 + -1.0 s3_month3 >= 0
#   DemandCap_i3_month4: x3_month4 + s3_month3 + -1.0 s3_month4 <= 400
#   NoNegSales_i3_month4: x3_month4 + s3_month3 + -1.0 s3_month4 >= 0
#   DemandCap_i3_month5: x3_month5 + s3_month4 + -1.0 s3_month5 <= 500
#   NoNegSales_i3_month5: x3_month5 + s3_month4 + -1.0 s3_month5 >= 0
#   DemandCap_i3_month6: x3_month6 + s3_month5 + -1.0 s3_month6 <= 100
#   NoNegSales_i3_month6: x3_month6 + s3_month5 + -1.0 s3_month6 >= 0
#   DemandCap_i4_month1: x4_month1 + -1.0 s4_month1 <= 300
#   NoNegSales_i4_month1: x4_month1 + -1.0 s4_month1 >= 0
#   DemandCap_i4_month2: x4_month2 + s4_month1 + -1.0 s4_month2 <= 0
#   NoNegSales_i4_month2: x4_month2 + s4_month1 + -1.0 s4_month2 >= 0
#   DemandCap_i4_month3: x4_month3 + s4_month2 + -1.0 s4_month3 <= 0
#   NoNegSales_i4_month3: x4_month3 + s4_month2 + -1.0 s4_month3 >= 0
#   DemandCap_i4_month4: x4_month4 + s4_month3 + -1.0 s4_month4 <= 500
#   NoNegSales_i4_month4: x4_month4 + s4_month3 + -1.0 s4_month4 >= 0
#   DemandCap_i4_month5: x4_month5 + s4_month4 + -1.0 s4_month5 <= 100
#   NoNegSales_i4_month5: x4_month5 + s4_month4 + -1.0 s4_month5 >= 0
#   DemandCap_i4_month6: x4_month6 + s4_month5 + -1.0 s4_month6 <= 300
#   NoNegSales_i4_month6: x4_month6 + s4_month5 + -1.0 s4_month6 >= 0
#   DemandCap_i5_month1: x5_month1 + -1.0 s5_month1 <= 800
#   NoNegSales_i5_month1: x5_month1 + -1.0 s5_month1 >= 0
#   DemandCap_i5_month2: x5_month2 + s5_month1 + -1.0 s5_month2 <= 400
#   NoNegSales_i5_month2: x5_month2 + s5_month1 + -1.0 s5_month2 >= 0
#   DemandCap_i5_month3: x5_month3 + s5_month2 + -1.0 s5_month3 <= 500
#   NoNegSales_i5_month3: x5_month3 + s5_month2 + -1.0 s5_month3 >= 0
#   DemandCap_i5_month4: x5_month4 + s5_month3 + -1.0 s5_month4 <= 200
#   NoNegSales_i5_month4: x5_month4 + s5_month3 + -1.0 s5_month4 >= 0
#   DemandCap_i5_month5: x5_month5 + s5_month4 + -1.0 s5_month5 <= 1000
#   NoNegSales_i5_month5: x5_month5 + s5_month4 + -1.0 s5_month5 >= 0
#   DemandCap_i5_month6: x5_month6 + s5_month5 + -1.0 s5_month6 <= 1100
#   NoNegSales_i5_month6: x5_month6 + s5_month5 + -1.0 s5_month6 >= 0
#   DemandCap_i6_month1: x6_month1 + -1.0 s6_month1 <= 200
#   NoNegSales_i6_month1: x6_month1 + -1.0 s6_month1 >= 0
#   DemandCap_i6_month2: x6_month2 + s6_month1 + -1.0 s6_month2 <= 300
#   NoNegSales_i6_month2: x6_month2 + s6_month1 + -1.0 s6_month2 >= 0
#   DemandCap_i6_month3: x6_month3 + s6_month2 + -1.0 s6_month3 <= 400
#   NoNegSales_i6_month3: x6_month3 + s6_month2 + -1.0 s6_month3 >= 0
#   DemandCap_i6_month4: x6_month4 + s6_month3 + -1.0 s6_month4 <= 0
#   NoNegSales_i6_month4: x6_month4 + s6_month3 + -1.0 s6_month4 >= 0
#   DemandCap_i6_month5: x6_month5 + s6_month4 + -1.0 s6_month5 <= 300
#   NoNegSales_i6_month5: x6_month5 + s6_month4 + -1.0 s6_month5 >= 0
#   DemandCap_i6_month6: x6_month6 + s6_month5 + -1.0 s6_month6 <= 500
#   NoNegSales_i6_month6: x6_month6 + s6_month5 + -1.0 s6_month6 >= 0
#   DemandCap_i7_month1: x7_month1 + -1.0 s7_month1 <= 100
#   NoNegSales_i7_month1: x7_month1 + -1.0 s7_month1 >= 0
#   DemandCap_i7_month2: x7_month2 + s7_month1 + -1.0 s7_month2 <= 150
#   NoNegSales_i7_month2: x7_month2 + s7_month1 + -1.0 s7_month2 >= 0
#   DemandCap_i7_month3: x7_month3 + s7_month2 + -1.0 s7_month3 <= 100
#   NoNegSales_i7_month3: x7_month3 + s7_month2 + -1.0 s7_month3 >= 0
#   DemandCap_i7_month4: x7_month4 + s7_month3 + -1.0 s7_month4 <= 100
#   NoNegSales_i7_month4: x7_month4 + s7_month3 + -1.0 s7_month4 >= 0
#   DemandCap_i7_month5: x7_month5 + s7_month4 + -1.0 s7_month5 <= 0
#   NoNegSales_i7_month5: x7_month5 + s7_month4 + -1.0 s7_month5 >= 0
#   DemandCap_i7_month6: x7_month6 + s7_month5 + -1.0 s7_month6 <= 60
#   NoNegSales_i7_month6: x7_month6 + s7_month5 + -1.0 s7_month6 >= 0
#   StorageLimit_i1_month1: s1_month1 <= 100
#   StorageLimit_i2_month1: s2_month1 <= 100
#   StorageLimit_i3_month1: s3_month1 <= 100
#   StorageLimit_i4_month1: s4_month1 <= 100
#   StorageLimit_i5_month1: s5_month1 <= 100
#   StorageLimit_i6_month1: s6_month1 <= 100
#   StorageLimit_i7_month1: s7_month1 <= 100
#   StorageLimit_i1_month2: s1_month2 <= 100
#   StorageLimit_i2_month2: s2_month2 <= 100
#   StorageLimit_i3_month2: s3_month2 <= 100
#   StorageLimit_i4_month2: s4_month2 <= 100
#   StorageLimit_i5_month2: s5_month2 <= 100
#   StorageLimit_i6_month2: s6_month2 <= 100
#   StorageLimit_i7_month2: s7_month2 <= 100
#   StorageLimit_i1_month3: s1_month3 <= 100
#   StorageLimit_i2_month3: s2_month3 <= 100
#   StorageLimit_i3_month3: s3_month3 <= 100
#   StorageLimit_i4_month3: s4_month3 <= 100
#   StorageLimit_i5_month3: s5_month3 <= 100
#   StorageLimit_i6_month3: s6_month3 <= 100
#   StorageLimit_i7_month3: s7_month3 <= 100
#   StorageLimit_i1_month4: s1_month4 <= 100
#   StorageLimit_i2_month4: s2_month4 <= 100
#   StorageLimit_i3_month4: s3_month4 <= 100
#   StorageLimit_i4_month4: s4_month4 <= 100
#   StorageLimit_i5_month4: s5_month4 <= 100
#   StorageLimit_i6_month4: s6_month4 <= 100
#   StorageLimit_i7_month4: s7_month4 <= 100
#   StorageLimit_i1_month5: s1_month5 <= 100
#   StorageLimit_i2_month5: s2_month5 <= 100
#   StorageLimit_i3_month5: s3_month5 <= 100
#   StorageLimit_i4_month5: s4_month5 <= 100
#   StorageLimit_i5_month5: s5_month5 <= 100
#   StorageLimit_i6_month5: s6_month5 <= 100
#   StorageLimit_i7_month5: s7_month5 <= 100
#   StorageLimit_i1_month6: s1_month6 <= 100
#   StorageLimit_i2_month6: s2_month6 <= 100
#   StorageLimit_i3_month6: s3_month6 <= 100
#   StorageLimit_i4_month6: s4_month6 <= 100
#   StorageLimit_i5_month6: s5_month6 <= 100
#   StorageLimit_i6_month6: s6_month6 <= 100
#   StorageLimit_i7_month6: s7_month6 <= 100
#   EndingInventory_i1: s1_month6 >= 50
#   EndingInventory_i2: s2_month6 >= 50
#   EndingInventory_i3: s3_month6 >= 50
#   EndingInventory_i4: s4_month6 >= 50
#   EndingInventory_i5: s5_month6 >= 50
#   EndingInventory_i6: s6_month6 >= 50
#   EndingInventory_i7: s7_month6 >= 50
# C:\Users\zungz\AppData\Local\Temp\ipykernel_34928\1574255693.py:2: DeprecationWarning: Model.display() is deprecated
#   m.display()

# %%
# Solve
m.update()
m.optimize()

# Getting the results out
print(f'\nTo generate the optimal profit of ${m.ObjVal:0.2f} from January to June:')
for t in months:
    for i in products:
        print(f'In month {t+1}, make {x[t][i].X:.1f} and store {s[t][i].X:.1f} units of product {i+1}.')
# Out:
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: AMD Ryzen 9 8945HS w/ Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 163 rows, 84 columns and 407 nonzeros
# Model fingerprint: 0xe9c96713
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [5e-01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 2e+03]
# Presolve removed 158 rows and 71 columns
# Presolve time: 0.01s
# Presolved: 5 rows, 16 columns, 21 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0497786e+05   3.299124e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 4
#        7    9.3715179e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.371517857e+04
#
# To generate the optimal profit of $93715.18 from January to June:
# In month 1, make 500.0 and store 0.0 units of product 1.
# In month 1, make 888.6 and store 0.0 units of product 2.
# In month 1, make 382.5 and store 82.5 units of product 3.
# In month 1, make 300.0 and store 0.0 units of product 4.
# In month 1, make 800.0 and store 0.0 units of product 5.
# In month 1, make 200.0 and store 0.0 units of product 6.
# In month 1, make 0.0 and store 0.0 units of product 7.
# In month 2, make 700.0 and store 100.0 units of product 1.
# In month 2, make 600.0 and store 100.0 units of product 2.
# In month 2, make 117.5 and store 0.0 units of product 3.
# In month 2, make 0.0 and store 0.0 units of product 4.
# In month 2, make 500.0 and store 100.0 units of product 5.
# In month 2, make 300.0 and store 0.0 units of product 6.
# In month 2, make 250.0 and store 100.0 units of product 7.
# In month 3, make 0.0 and store 0.0 units of product 1.
# In month 3, make 0.0 and store 0.0 units of product 2.
# In month 3, make 0.0 and store 0.0 units of product 3.
# In month 3, make 0.0 and store 0.0 units of product 4.
# In month 3, make 0.0 and store 0.0 units of product 5.
# In month 3, make 400.0 and store 0.0 units of product 6.
# In month 3, make 0.0 and store 0.0 units of product 7.
# In month 4, make 200.0 and store 0.0 units of product 1.
# In month 4, make 300.0 and store 0.0 units of product 2.
# In month 4, make 400.0 and store 0.0 units of product 3.
# In month 4, make 500.0 and store 0.0 units of product 4.
# In month 4, make 200.0 and store 0.0 units of product 5.
# In month 4, make 0.0 and store 0.0 units of product 6.
# In month 4, make 100.0 and store 0.0 units of product 7.
# In month 5, make 0.0 and store 0.0 units of product 1.
# In month 5, make 100.0 and store 0.0 units of product 2.
# In month 5, make 600.0 and store 100.0 units of product 3.
# In month 5, make 100.0 and store 0.0 units of product 4.
# In month 5, make 1100.0 and store 100.0 units of product 5.
# In month 5, make 300.0 and store 0.0 units of product 6.
# In month 5, make 100.0 and store 100.0 units of product 7.
# In month 6, make 550.0 and store 50.0 units of product 1.
# In month 6, make 550.0 and store 50.0 units of product 2.
# In month 6, make 0.0 and store 50.0 units of product 3.
# In month 6, make 350.0 and store 50.0 units of product 4.
# In month 6, make 0.0 and store 50.0 units of product 5.
# In month 6, make 550.0 and store 50.0 units of product 6.
# In month 6, make 0.0 and store 50.0 units of product 7.

# %%
# Get the sensitivity analysis
con = sp.sa_constrs(m.getConstrs())

# Only machine constraints
machines = ['grinder', 'vertical', 'horizontal', 'borer', 'planer']
machine_constrs = con[con.index.str.startswith(tuple(machines))]

# Positive shadow prices
machine_constrs[machine_constrs['shadow_price'] > 0]
# Out:
#              binding?  final_value     RHS  slack  shadow_price  \
# grinder_1     binding       1152.0  1152.0    0.0      8.571429
# horizontal_2  binding        384.0   384.0    0.0      0.625000
# borer_3       binding          0.0     0.0    0.0    200.000000
# planer_6      binding          0.0     0.0    0.0    800.000000
#
#               range_feas_low  range_feas_high
# grinder_1              530.0           1230.0
# horizontal_2           370.0            450.0
# borer_3                  0.0             10.0
# planer_6                 0.0              0.5
